# %% [markdown]
# <a href="https://colab.research.google.com/github/AIPythonILP-teamB/AIPythonILP-teamB-Python/blob/main/weather_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install japanize-matplotlib
import numpy as np
# 表データを扱うライブラリ pandas をインポート
import pandas as pd
# 図や表を描画するためのライブラリをインポート
import matplotlib.pyplot as plt
import japanize_matplotlib
import seaborn as sns
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 30.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for japanize-matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=c66eeb964c4957267401b15cec23fd9ba35d20b15880d1a612cbf20190662dac
#   Stored in directory: /root/.cache/pip/wheels/da/a1/71/b8faeb93276fed10edffcca20746f1ef6f8d9e071eee8425fc
# Successfully built japanize-matplotlib
# ...

# %%
import pandas as pd


df = pd.read_csv("data.csv", encoding="cp932", skiprows=3, header=0)
df.drop([0, 1], axis=0, inplace=True)

# %%
df.head()
# Out:
#         年月日 曜日  平均気温(℃)  降水量の合計(mm) 降水量の合計(mm).1  日照時間(時間) 日照時間(時間).1  \
# 2  2024/4/1  月     14.6         3.0            0       3.8          0
# 3  2024/4/2  火     14.2         0.0            1      10.6          0
# 4  2024/4/3  水     13.9        11.5            0       0.0          0
# 5  2024/4/4  木     15.4         4.0            0       0.1          0
# 6  2024/4/5  金     11.4         0.5            0       0.0          0
#
#    合計全天日射量(MJ/㎡)  平均風速(m/s)  平均蒸気圧(hPa)  平均湿度(％)  平均雲量(10分比)  最高気温(℃)  \
# 2          14.85        2.8        11.9     73.0         6.0     19.7
# 3          22.30        3.0         8.2     50.0         5.0     20.6
# 4           4.58        1.6        13.0     83.0        10.0     16.6
# 5           9.27        2.0        13.6     79.0        10.0     19.9
# 6           2.97        2.8         9.6     71.0        10.0     15.1
#
#    最低気温(℃)  1時間降水量の最大(mm) 1時間降水量の最大(mm).1  最大風速(m/s) 最大風速(m/s).1  最小相対湿度(％)
# ...

# %%
df = df.drop(columns=[ '降水量の合計(mm).1',  '日照時間(時間).1','1時間降水量の最大(mm).1','最大風速(m/s).1'])

# %%
df = df[df['曜日'] != '日']
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (313, 15)

# %%
df.rename(columns={'年月日': '日付'}, inplace=True)

print(df)
# Out:
#             日付 曜日  平均気温(℃)  降水量の合計(mm)  日照時間(時間)  合計全天日射量(MJ/㎡)  平均風速(m/s)  \
# 0     2024/4/1  月     14.6         3.0       3.8          14.85        2.8
# 1     2024/4/2  火     14.2         0.0      10.6          22.30        3.0
# 2     2024/4/3  水     13.9        11.5       0.0           4.58        1.6
# 3     2024/4/4  木     15.4         4.0       0.1           9.27        2.0
# 4     2024/4/5  金     11.4         0.5       0.0           2.97        2.8
# ..         ... ..      ...         ...       ...            ...        ...
# 308  2025/3/26  水     20.4         0.0      10.2          19.81        3.8
# 309  2025/3/27  木     17.9         0.0       5.6          17.49        3.8
# 310  2025/3/28  金     19.9         2.5       4.1          14.41        4.2
# 311  2025/3/29  土      7.6        12.5       0.0           2.51        3.1
# 312  2025/3/31  月      7.0         0.0       0.0           7.34        3.0
#
# ...

# %%
df.to_csv('weather_data_cleaned.csv', index=False)
